# %%
#資料讀取
#from google.colab import files
import pandas as pd
#upload = files.upload()
train_data = pd.read_csv("Train_AQI.csv")
test_data = pd.read_csv("Test_AQI.csv")

# %%
#套件載入
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense,GRU,Flatten
from keras.callbacks import EarlyStopping
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error

# %%
#NO2欄位統計分析
train_data['NO2(GT)'].describe()
# Out:
# count    3996.000000
# mean       78.640390
# std        48.652959
# min         0.000000
# 25%        47.000000
# 50%        84.000000
# 75%       114.000000
# max       233.000000
# Name: NO2(GT), dtype: float64

# %%
#繪製NO2盒形圖
plt.boxplot(train_data['NO2(GT)'],showmeans=True)
plt.title('NO2(GT)')
plt.show()

# %%
#利用IOR刪除離群值
print ("Shape Of The Before Ouliers: ",train_data['NO2(GT)'].shape)
n=1.5
IQR = np.percentile(train_data['NO2(GT)'],75) - np.percentile(train_data['NO2(GT)'],25)
train_data=train_data[train_data['NO2(GT)'] < np.percentile(train_data['NO2(GT)'],75)+n*IQR]
train_data=train_data[train_data['NO2(GT)'] > np.percentile(train_data['NO2(GT)'],25)-n*IQR]
print ("Shape Of The After Ouliers: ",train_data['NO2(GT)'].shape)
# Out:
# Shape Of The Before Ouliers:  (3996,)
# Shape Of The After Ouliers:  (3992,)

# %%
#刪除離群值後將N02資料格式轉換為DataFrame
training_set=pd.DataFrame(train_data['NO2(GT)'])
training_set
# Out:
#       NO2(GT)
# 0         113
# 1          92
# 2         114
# 3         122
# 4         116
# ...       ...
# 3991       50
# 3992       34
# 3993        0
# 3994       21
# 3995       48
#
# [3992 rows x 1 columns]

# %%
#正規化
mm=MinMaxScaler(feature_range=(0,1))
training_set_mm=mm.fit_transform(training_set)

# %%
#設定訓練資料的timestep
x_train=[]
y_train=[]
for i in range(48,3992):
    x_train.append(training_set_mm[i-48:i,0])
    y_train.append(training_set_mm[i,0])
x_train,y_train=np.array(x_train),np.array(y_train)

# %%
#將資料升維(二維升三維(aqi,timesteps,indicators))
x_train = np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))

# %%
#設定callbacks
earlystop=EarlyStopping(monitor='val_loss',patience=2)

# %%
#模型建立
model=Sequential()
model.add(GRU(units=48,return_sequences=True,input_shape=(x_train.shape[1],1)))
model.add(GRU(units=192,return_sequences=True))
model.add(Flatten())
model.add(Dense(48))
model.add(Dense(1))

model.compile(loss='mean_squared_error',optimizer='SGD',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 48, 48)            7344
#
#  gru_1 (GRU)                 (None, 48, 192)           139392
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 48)                442416
#
#  dense_1 (Dense)             (None, 1)                 49
#
# =================================================================
# Total params: 589,201
# Trainable params: 589,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
#模型訓練
model.fit(x_train,y_train,epochs=30,validation_data=(x_train,y_train),batch_size=32,callbacks=earlystop)
# Out:
# Epoch 1/30
# 124/124 [==============================] - 9s 59ms/step - loss: 0.0398 - accuracy: 0.1694 - val_loss: 0.0327 - val_accuracy: 0.1691
# Epoch 2/30
# 124/124 [==============================] - 7s 56ms/step - loss: 0.0291 - accuracy: 0.1696 - val_loss: 0.0263 - val_accuracy: 0.1686
# Epoch 3/30
# 124/124 [==============================] - 21s 171ms/step - loss: 0.0247 - accuracy: 0.1689 - val_loss: 0.0233 - val_accuracy: 0.1686
# Epoch 4/30
# 124/124 [==============================] - 22s 179ms/step - loss: 0.0223 - accuracy: 0.1689 - val_loss: 0.0218 - val_accuracy: 0.1689
# Epoch 5/30
# 124/124 [==============================] - 21s 170ms/step - loss: 0.0207 - accuracy: 0.1689 - val_loss: 0.0202 - val_accuracy: 0.1676
# Epoch 6/30
# 124/124 [==============================] - 18s 149ms/step - loss: 0.0198 - accuracy: 0.1678 - val_loss: 0.0191 - val_accuracy: 0.1681
# Epoch 7/30
# 124/124 [==============================] - 8s 66ms/step - loss: 0.0189 - accuracy: 0.1684 - val_loss: 0.0184 - val_accuracy: 0.1678
# Epoch 8/30
# 124/124 [==============================] - 16s 126ms/step - loss: 0.0184 - accuracy: 0.1681 - val_loss: 0.0179 - val_accuracy: 0.1678
# Epoch 9/30
# 124/124 [==============================] - 22s 175ms/step - loss: 0.0179 - accuracy: 0.1676 - val_loss: 0.0175 - val_accuracy: 0.1678
# Epoch 10/30
# 124/124 [==============================] - 21s 169ms/step - loss: 0.0175 - accuracy: 0.1678 - val_loss: 0.0174 - val_accuracy: 0.1684
# Epoch 11/30
# 124/124 [==============================] - 11s 86ms/step - loss: 0.0172 - accuracy: 0.1678 - val_loss: 0.0169 - val_accuracy: 0.1678
# Epoch 12/30
# 124/124 [==============================] - 11s 85ms/step - loss: 0.0169 - accuracy: 0.1681 - val_loss: 0.0168 - val_accuracy: 0.1678
# Epoch 13/30
# 124/124 [==============================] - 13s 101ms/step - loss: 0.0166 - accuracy: 0.1678 - val_loss: 0.0164 - val_accuracy: 0.1678
# Epoch 14/30
# 124/124 [==============================] - 22s 177ms/step - loss: 0.0164 - accuracy: 0.1676 - val_loss: 0.0189 - val_accuracy: 0.1671
# Epoch 15/30
# 124/124 [==============================] - 13s 105ms/step - loss: 0.0163 - accuracy: 0.1678 - val_loss: 0.0161 - val_accuracy: 0.1678
# Epoch 16/30
# 124/124 [==============================] - 19s 153ms/step - loss: 0.0161 - accuracy: 0.1678 - val_loss: 0.0160 - val_accuracy: 0.1678
# Epoch 17/30
# 124/124 [==============================] - 16s 131ms/step - loss: 0.0159 - accuracy: 0.1678 - val_loss: 0.0159 - val_accuracy: 0.1678
# Epoch 18/30
# 124/124 [==============================] - 14s 113ms/step - loss: 0.0159 - accuracy: 0.1678 - val_loss: 0.0156 - val_accuracy: 0.1678
# Epoch 19/30
# 124/124 [==============================] - 25s 201ms/step - loss: 0.0156 - accuracy: 0.1678 - val_loss: 0.0158 - val_accuracy: 0.1676
# Epoch 20/30
# 124/124 [==============================] - 22s 180ms/step - loss: 0.0156 - accuracy: 0.1676 - val_loss: 0.0163 - val_accuracy: 0.1686

# %%
test_data['NO2(GT)'].describe()
# Out:
# count    1122.000000
# mean       56.131907
# std        59.367635
# min         0.000000
# 25%         0.000000
# 50%        52.000000
# 75%       101.000000
# max       225.000000
# Name: NO2(GT), dtype: float64

# %%
plt.boxplot(train_data['NO2(GT)'],showmeans=True)
plt.title('NO2(GT)')
plt.show()

# %%
testing_set=pd.DataFrame(test_data['NO2(GT)'])

# %%
#正規化
testing_set_mm=mm.fit_transform(testing_set)

# %%
#設定測試資料的timestep
x_test=[]
y_test=[]
for i in range(48,1122):
    x_test.append(testing_set_mm[i-48:i,0])
    y_test.append(testing_set_mm[i,0])
x_test,y_test=np.array(x_test),np.array(y_test)

# %%
#將資料升維(二維升三維(aqi,timesteps,indicators))
x_test=np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

# %%
#進行預測
predict_data=model.predict(x_test)

# %%
#將預測資料還原
predict_data=mm.inverse_transform(predict_data)

# %%
#可視化預測成果
plt.plot(testing_set,color='red',label='actual NO2(GT) concentration')
plt.plot(predict_data,color='blue',label='predict NO2(GT) concentration')
plt.title('NO2 Concentration Prediction')
plt.xlabel('Time')
plt.ylabel('NO2 Concentration')
plt.legend()
plt.show()

# %%
#績效評估
print("loss:",model.evaluate(x_train,y_train))
print("mae:",mean_absolute_error(y_test,predict_data))
print("mape:",mean_absolute_percentage_error(y_test,predict_data))
print("rmse:",np.sqrt(mean_squared_error(y_test,predict_data)))
# Out:
# 124/124 [==============================] - 5s 37ms/step - loss: 0.0163 - accuracy: 0.1686
# loss: [0.01632555201649666, 0.16861054301261902]
# mae: 53.8092103152036
# mape: 3.58713698146323e+16
# rmse: 71.01467835666998
